# %%
count = 0
for x in feature_docs:
    print(x.name)
    print(len(x.componentDefinitions))
    for comp_def in x.componentDefinitions:
        if sbol2.BIOPAX_DNA not in comp_def.types:
            continue
        else:
            count += 1
print(count)
